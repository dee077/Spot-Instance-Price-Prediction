# %% [markdown]
# ## Amazon EC2 Spot Price Data analysis
#
# Amazon web services provides different pricing models pay-per-use, fixed, and auction-based (spot price). It is seen that the spot price is a minimum of 5 times cheaper than the other pricing models but there is no guarentee that you will be given the instance. It depends on the price you bid. Thus, analysis of historical data for spot price inorder to efficiently (minimal cost) schedule the jobs is important.

# %% [markdown]
# Boto3 is a python library (Amazon Api) for pulling the price history. It provides trailing data upto 90 days.

# %%
# Importing the necessary packages.

import boto3
import pandas as pd
import datetime

# %% [markdown]
# Below is the code to pull the data. The key method is describe_spot_price_history. The handler takes input for the start and end times for the data you are interested in, instance type, region, Product Description. Remember amazon provides only the most recent 90 days of price history. The code is facilitated to provide a list of instance type if we are interested in multiple instance types and so with the product description.

# %%
def handler(event, context):
    start_time = event['start_time']
    end_time = event ['end_time']
    region = event['region']
    product_description = event['product_description']
    client = boto3.client('ec2', region_name=region)
    response = client.describe_spot_price_history(
        InstanceTypes=event['instances_list'],
        ProductDescriptions=product_description,
        StartTime=start_time,
        EndTime = end_time,
        MaxResults=10000
    )
    return response['SpotPriceHistory']

# %% [markdown]
# Below is the wrapper to the handler that takes the list of input values the user is interested in and invokes the handler with those input values.

# %%
def wrapper(instanceList, ProductDescriptionList, region):
    m4_list = []
    for i in range(1,90):
        output = (handler({
        'instances_list': instanceList,
        'start_time': datetime.datetime.now() - datetime.timedelta(i),
        'end_time': datetime.datetime.now() - datetime.timedelta(i-1),
        'product_description': ProductDescriptionList,
        'region': region
    }, ''))
        for j in range(0,len(output)):
            m4_list.append(output[j])

    df = pd.DataFrame(m4_list)
    df = df.drop_duplicates()
    df.reset_index(drop=True,inplace=True)
    return df

# %% [markdown]
# The wrapper pulls the price history and returns the data as a dataframe.

# %%
df = wrapper(['m4.large', 'm4.xlarge'],['Linux/UNIX (Amazon VPC)'], 'us-west-2')
df
# Out:
#       AvailabilityZone InstanceType ProductDescription SpotPrice  \
# 0           us-west-2c    m4.xlarge         Linux/UNIX  0.060200
# 1           us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 2           us-west-2b    m4.xlarge         Linux/UNIX  0.060200
# 3           us-west-2c     m4.large         Linux/UNIX  0.030100
# 4           us-west-2a     m4.large         Linux/UNIX  0.030100
# 5           us-west-2b     m4.large         Linux/UNIX  0.030100
# 6           us-west-2c    m4.xlarge         Linux/UNIX  0.060200
# 7           us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 8           us-west-2b    m4.xlarge         Linux/UNIX  0.060200
# 9           us-west-2c     m4.large         Linux/UNIX  0.030100
# 10          us-west-2a     m4.large         Linux/UNIX  0.030100
# 11          us-west-2b     m4.large         Linux/UNIX  0.030100
# 12          us-west-2c    m4.xlarge         Linux/UNIX  0.060200
# 13          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 14          us-west-2b    m4.xlarge         Linux/UNIX  0.060200
# 15          us-west-2c     m4.large         Linux/UNIX  0.030100
# 16          us-west-2a     m4.large         Linux/UNIX  0.030100
# 17          us-west-2b     m4.large         Linux/UNIX  0.030100
# 18          us-west-2c     m4.large         Linux/UNIX  0.030100
# 19          us-west-2a     m4.large         Linux/UNIX  0.030100
# 20          us-west-2b     m4.large         Linux/UNIX  0.030100
# 21          us-west-2c    m4.xlarge         Linux/UNIX  0.060200
# 22          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 23          us-west-2b    m4.xlarge         Linux/UNIX  0.060200
# 24          us-west-2c     m4.large         Linux/UNIX  0.030100
# 25          us-west-2a     m4.large         Linux/UNIX  0.030100
# 26          us-west-2b     m4.large         Linux/UNIX  0.030100
# 27          us-west-2c    m4.xlarge         Linux/UNIX  0.060200
# 28          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 29          us-west-2b    m4.xlarge         Linux/UNIX  0.060200
# ...                ...          ...                ...       ...
# 33271       us-west-2a    m4.xlarge         Linux/UNIX  0.065700
# 33272       us-west-2b    m4.xlarge         Linux/UNIX  0.063200
# 33273       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33274       us-west-2a    m4.xlarge         Linux/UNIX  0.065700
# 33275       us-west-2c     m4.large         Linux/UNIX  0.029800
# 33276       us-west-2c    m4.xlarge         Linux/UNIX  0.065700
# 33277       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33278       us-west-2c    m4.xlarge         Linux/UNIX  0.065800
# 33279       us-west-2b    m4.xlarge         Linux/UNIX  0.063300
# 33280       us-west-2c    m4.xlarge         Linux/UNIX  0.065700
# 33281       us-west-2a    m4.xlarge         Linux/UNIX  0.065900
# 33282       us-west-2b    m4.xlarge         Linux/UNIX  0.063400
# 33283       us-west-2b    m4.xlarge         Linux/UNIX  0.063500
# 33284       us-west-2c    m4.xlarge         Linux/UNIX  0.065800
# 33285       us-west-2a    m4.xlarge         Linux/UNIX  0.066000
# 33286       us-west-2b    m4.xlarge         Linux/UNIX  0.063600
# 33287       us-west-2c    m4.xlarge         Linux/UNIX  0.065900
# 33288       us-west-2b    m4.xlarge         Linux/UNIX  0.063500
# 33289       us-west-2c    m4.xlarge         Linux/UNIX  0.065800
# 33290       us-west-2b    m4.xlarge         Linux/UNIX  0.063600
# 33291       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
# 33292       us-west-2b    m4.xlarge         Linux/UNIX  0.063700
# 33293       us-west-2a    m4.xlarge         Linux/UNIX  0.066200
# 33294       us-west-2c    m4.xlarge         Linux/UNIX  0.065700
# 33295       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
# 33296       us-west-2c    m4.xlarge         Linux/UNIX  0.065600
# 33297       us-west-2a    m4.xlarge         Linux/UNIX  0.066000
# 33298       us-west-2c    m4.xlarge         Linux/UNIX  0.065500
# 33299       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
# 33300       us-west-2c    m4.xlarge         Linux/UNIX  0.065400
#
#                       Timestamp
# 0     2018-01-17 15:29:29+00:00
# 1     2018-01-17 15:29:29+00:00
# 2     2018-01-17 15:29:29+00:00
# 3     2018-01-17 12:29:47+00:00
# 4     2018-01-17 12:29:47+00:00
# 5     2018-01-17 12:29:47+00:00
# 6     2018-01-17 00:29:48+00:00
# 7     2018-01-17 00:29:48+00:00
# 8     2018-01-17 00:29:48+00:00
# 9     2018-01-16 21:29:47+00:00
# 10    2018-01-16 21:29:47+00:00
# 11    2018-01-16 21:29:47+00:00
# 12    2018-01-16 10:29:28+00:00
# 13    2018-01-16 10:29:28+00:00
# 14    2018-01-16 10:29:28+00:00
# 15    2018-01-16 07:29:28+00:00
# 16    2018-01-16 07:29:28+00:00
# 17    2018-01-16 07:29:28+00:00
# 18    2018-01-15 21:30:03+00:00
# 19    2018-01-15 21:30:03+00:00
# 20    2018-01-15 21:30:03+00:00
# 21    2018-01-15 19:29:44+00:00
# 22    2018-01-15 19:29:44+00:00
# 23    2018-01-15 19:29:44+00:00
# 24    2018-01-14 21:30:03+00:00
# 25    2018-01-14 21:30:03+00:00
# 26    2018-01-14 21:30:03+00:00
# 27    2018-01-15 04:29:46+00:00
# 28    2018-01-15 04:29:46+00:00
# 29    2018-01-15 04:29:46+00:00
# ...                         ...
# 33271 2017-10-20 21:30:23+00:00
# 33272 2017-10-20 21:29:49+00:00
# 33273 2017-10-20 21:29:27+00:00
# 33274 2017-10-20 21:29:15+00:00
# 33275 2017-10-20 21:29:14+00:00
# 33276 2017-10-20 21:28:57+00:00
# 33277 2017-10-20 21:28:57+00:00
# 33278 2017-10-20 21:28:43+00:00
# 33279 2017-10-20 21:28:41+00:00
# 33280 2017-10-20 21:28:07+00:00
# 33281 2017-10-20 21:28:07+00:00
# 33282 2017-10-20 21:27:33+00:00
# 33283 2017-10-20 21:27:31+00:00
# 33284 2017-10-20 21:27:09+00:00
# 33285 2017-10-20 21:27:09+00:00
# 33286 2017-10-20 21:27:09+00:00
# 33287 2017-10-20 21:26:35+00:00
# 33288 2017-10-20 21:26:35+00:00
# 33289 2017-10-20 21:24:53+00:00
# 33290 2017-10-20 21:24:53+00:00
# 33291 2017-10-20 21:22:49+00:00
# 33292 2017-10-20 21:22:19+00:00
# 33293 2017-10-20 21:21:11+00:00
# 33294 2017-10-20 21:21:01+00:00
# 33295 2017-10-20 21:20:35+00:00
# 33296 2017-10-20 21:20:31+00:00
# 33297 2017-10-20 21:18:29+00:00
# 33298 2017-10-20 21:17:43+00:00
# 33299 2017-10-20 21:17:43+00:00
# 33300 2017-10-20 21:17:29+00:00
#
# [33301 rows x 5 columns]

# %% [markdown]
# Simply by changing the arguments to the wrapper we can pull the required data. This two fold wrapper - handler is written with intent to increase the ease of integration to other interfaces. For example one can build a query interface on top of this and can have the data fetched. The integration is simplified.

# %% [markdown]
# ## Data Analysis
#
# #### Getting to know about the data
# There are different types of instance types provided by amazon. The case is similar with the Product Description. The different instance types, their use cases and specifications are posted on the amazon web services site. https://aws.amazon.com/ec2/instance-types/
#
# More about spot instances can be learnt from https://aws.amazon.com/ec2/spot/

# %%
df.AvailabilityZone.value_counts()
# Out:
# us-west-2a    13184
# us-west-2b    11883
# us-west-2c     8234
# Name: AvailabilityZone, dtype: int64

# %%
df.ProductDescription.value_counts()
# Out:
# Linux/UNIX    33301
# Name: ProductDescription, dtype: int64

# %%
df.dtypes
# Out:
# AvailabilityZone                   object
# InstanceType                       object
# ProductDescription                 object
# SpotPrice                          object
# Timestamp             datetime64[ns, UTC]
# dtype: object

# %%
## Select a particular criteria for analysis

uwta = df.loc[df['AvailabilityZone'] == 'us-west-2a']
uwta
# Out:
#       AvailabilityZone InstanceType ProductDescription SpotPrice  \
# 1           us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 4           us-west-2a     m4.large         Linux/UNIX  0.030100
# 7           us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 10          us-west-2a     m4.large         Linux/UNIX  0.030100
# 13          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 16          us-west-2a     m4.large         Linux/UNIX  0.030100
# 19          us-west-2a     m4.large         Linux/UNIX  0.030100
# 22          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 25          us-west-2a     m4.large         Linux/UNIX  0.030100
# 28          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 31          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 34          us-west-2a     m4.large         Linux/UNIX  0.030100
# 37          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 40          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 43          us-west-2a     m4.large         Linux/UNIX  0.030100
# 46          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 49          us-west-2a     m4.large         Linux/UNIX  0.030100
# 52          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 55          us-west-2a     m4.large         Linux/UNIX  0.030100
# 58          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 61          us-west-2a     m4.large         Linux/UNIX  0.030100
# 64          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 67          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 70          us-west-2a     m4.large         Linux/UNIX  0.030100
# 73          us-west-2a     m4.large         Linux/UNIX  0.030100
# 76          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 79          us-west-2a     m4.large         Linux/UNIX  0.030100
# 82          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# 85          us-west-2a     m4.large         Linux/UNIX  0.030100
# 88          us-west-2a    m4.xlarge         Linux/UNIX  0.060200
# ...                ...          ...                ...       ...
# 33223       us-west-2a    m4.xlarge         Linux/UNIX  0.064900
# 33226       us-west-2a    m4.xlarge         Linux/UNIX  0.065000
# 33231       us-west-2a    m4.xlarge         Linux/UNIX  0.065100
# 33232       us-west-2a    m4.xlarge         Linux/UNIX  0.065200
# 33233       us-west-2a    m4.xlarge         Linux/UNIX  0.065100
# 33235       us-west-2a    m4.xlarge         Linux/UNIX  0.064800
# 33237       us-west-2a    m4.xlarge         Linux/UNIX  0.064900
# 33241       us-west-2a    m4.xlarge         Linux/UNIX  0.065000
# 33243       us-west-2a    m4.xlarge         Linux/UNIX  0.065100
# 33244       us-west-2a    m4.xlarge         Linux/UNIX  0.065000
# 33245       us-west-2a    m4.xlarge         Linux/UNIX  0.065100
# 33247       us-west-2a    m4.xlarge         Linux/UNIX  0.065200
# 33250       us-west-2a    m4.xlarge         Linux/UNIX  0.065300
# 33252       us-west-2a    m4.xlarge         Linux/UNIX  0.065400
# 33254       us-west-2a    m4.xlarge         Linux/UNIX  0.065500
# 33258       us-west-2a    m4.xlarge         Linux/UNIX  0.065700
# 33260       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33265       us-west-2a    m4.xlarge         Linux/UNIX  0.065900
# 33267       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33271       us-west-2a    m4.xlarge         Linux/UNIX  0.065700
# 33273       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33274       us-west-2a    m4.xlarge         Linux/UNIX  0.065700
# 33277       us-west-2a    m4.xlarge         Linux/UNIX  0.065800
# 33281       us-west-2a    m4.xlarge         Linux/UNIX  0.065900
# 33285       us-west-2a    m4.xlarge         Linux/UNIX  0.066000
# 33291       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
# 33293       us-west-2a    m4.xlarge         Linux/UNIX  0.066200
# 33295       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
# 33297       us-west-2a    m4.xlarge         Linux/UNIX  0.066000
# 33299       us-west-2a    m4.xlarge         Linux/UNIX  0.066100
#
#                       Timestamp
# 1     2018-01-17 15:29:29+00:00
# 4     2018-01-17 12:29:47+00:00
# 7     2018-01-17 00:29:48+00:00
# 10    2018-01-16 21:29:47+00:00
# 13    2018-01-16 10:29:28+00:00
# 16    2018-01-16 07:29:28+00:00
# 19    2018-01-15 21:30:03+00:00
# 22    2018-01-15 19:29:44+00:00
# 25    2018-01-14 21:30:03+00:00
# 28    2018-01-15 04:29:46+00:00
# 31    2018-01-14 13:29:45+00:00
# 34    2018-01-13 21:29:41+00:00
# 37    2018-01-14 08:30:02+00:00
# 40    2018-01-13 08:29:42+00:00
# 43    2018-01-13 07:29:45+00:00
# 46    2018-01-12 18:29:44+00:00
# 49    2018-01-12 18:29:26+00:00
# 52    2018-01-12 04:29:27+00:00
# 55    2018-01-12 04:29:25+00:00
# 58    2018-01-11 22:30:45+00:00
# 61    2018-01-11 13:29:26+00:00
# 64    2018-01-10 23:29:26+00:00
# 67    2018-01-10 22:30:14+00:00
# 70    2018-01-10 22:29:42+00:00
# 73    2018-01-10 18:29:32+00:00
# 76    2018-01-09 22:29:38+00:00
# 79    2018-01-09 18:29:24+00:00
# 82    2018-01-09 04:29:24+00:00
# 85    2018-01-09 13:29:52+00:00
# 88    2018-01-08 22:29:36+00:00
# ...                         ...
# 33223 2017-10-20 21:58:33+00:00
# 33226 2017-10-20 21:58:19+00:00
# 33231 2017-10-20 21:56:13+00:00
# 33232 2017-10-20 21:55:47+00:00
# 33233 2017-10-20 21:55:01+00:00
# 33235 2017-10-20 21:51:33+00:00
# 33237 2017-10-20 21:50:33+00:00
# 33241 2017-10-20 21:48:17+00:00
# 33243 2017-10-20 21:48:11+00:00
# 33244 2017-10-20 21:47:35+00:00
# 33245 2017-10-20 21:47:29+00:00
# 33247 2017-10-20 21:46:29+00:00
# 33250 2017-10-20 21:44:27+00:00
# 33252 2017-10-20 21:43:29+00:00
# 33254 2017-10-20 21:42:11+00:00
# 33258 2017-10-20 21:40:11+00:00
# 33260 2017-10-20 21:39:31+00:00
# 33265 2017-10-20 21:36:37+00:00
# 33267 2017-10-20 21:35:41+00:00
# 33271 2017-10-20 21:30:23+00:00
# 33273 2017-10-20 21:29:27+00:00
# 33274 2017-10-20 21:29:15+00:00
# 33277 2017-10-20 21:28:57+00:00
# 33281 2017-10-20 21:28:07+00:00
# 33285 2017-10-20 21:27:09+00:00
# 33291 2017-10-20 21:22:49+00:00
# 33293 2017-10-20 21:21:11+00:00
# 33295 2017-10-20 21:20:35+00:00
# 33297 2017-10-20 21:18:29+00:00
# 33299 2017-10-20 21:17:43+00:00
#
# [13184 rows x 5 columns]

# %%
uwta_m4 = uwta.loc[uwta['InstanceType'] == 'm4.large']
uwta_m4
# Out:
#       AvailabilityZone InstanceType ProductDescription SpotPrice  \
# 4           us-west-2a     m4.large         Linux/UNIX  0.030100
# 10          us-west-2a     m4.large         Linux/UNIX  0.030100
# 16          us-west-2a     m4.large         Linux/UNIX  0.030100
# 19          us-west-2a     m4.large         Linux/UNIX  0.030100
# 25          us-west-2a     m4.large         Linux/UNIX  0.030100
# 34          us-west-2a     m4.large         Linux/UNIX  0.030100
# 43          us-west-2a     m4.large         Linux/UNIX  0.030100
# 49          us-west-2a     m4.large         Linux/UNIX  0.030100
# 55          us-west-2a     m4.large         Linux/UNIX  0.030100
# 61          us-west-2a     m4.large         Linux/UNIX  0.030100
# 70          us-west-2a     m4.large         Linux/UNIX  0.030100
# 73          us-west-2a     m4.large         Linux/UNIX  0.030100
# 79          us-west-2a     m4.large         Linux/UNIX  0.030100
# 85          us-west-2a     m4.large         Linux/UNIX  0.030100
# 91          us-west-2a     m4.large         Linux/UNIX  0.030100
# 97          us-west-2a     m4.large         Linux/UNIX  0.030100
# 100         us-west-2a     m4.large         Linux/UNIX  0.030100
# 106         us-west-2a     m4.large         Linux/UNIX  0.030100
# 112         us-west-2a     m4.large         Linux/UNIX  0.030100
# 118         us-west-2a     m4.large         Linux/UNIX  0.030100
# 124         us-west-2a     m4.large         Linux/UNIX  0.030100
# 130         us-west-2a     m4.large         Linux/UNIX  0.030100
# 136         us-west-2a     m4.large         Linux/UNIX  0.030100
# 142         us-west-2a     m4.large         Linux/UNIX  0.030100
# 148         us-west-2a     m4.large         Linux/UNIX  0.030100
# 151         us-west-2a     m4.large         Linux/UNIX  0.030100
# 157         us-west-2a     m4.large         Linux/UNIX  0.030100
# 163         us-west-2a     m4.large         Linux/UNIX  0.030100
# 169         us-west-2a     m4.large         Linux/UNIX  0.030100
# 172         us-west-2a     m4.large         Linux/UNIX  0.030100
# ...                ...          ...                ...       ...
# 32397       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32398       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32399       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32419       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32430       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32489       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32491       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32496       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32497       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32502       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32503       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32507       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32510       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32514       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32527       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32545       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32546       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32556       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32633       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32636       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32640       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32895       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32897       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32976       us-west-2a     m4.large         Linux/UNIX  0.029600
# 32979       us-west-2a     m4.large         Linux/UNIX  0.029700
# 32995       us-west-2a     m4.large         Linux/UNIX  0.029600
# 33185       us-west-2a     m4.large         Linux/UNIX  0.029700
# 33186       us-west-2a     m4.large         Linux/UNIX  0.029800
# 33201       us-west-2a     m4.large         Linux/UNIX  0.029700
# 33218       us-west-2a     m4.large         Linux/UNIX  0.029800
#
#                       Timestamp
# 4     2018-01-17 12:29:47+00:00
# 10    2018-01-16 21:29:47+00:00
# 16    2018-01-16 07:29:28+00:00
# 19    2018-01-15 21:30:03+00:00
# 25    2018-01-14 21:30:03+00:00
# 34    2018-01-13 21:29:41+00:00
# 43    2018-01-13 07:29:45+00:00
# 49    2018-01-12 18:29:26+00:00
# 55    2018-01-12 04:29:25+00:00
# 61    2018-01-11 13:29:26+00:00
# 70    2018-01-10 22:29:42+00:00
# 73    2018-01-10 18:29:32+00:00
# 79    2018-01-09 18:29:24+00:00
# 85    2018-01-09 13:29:52+00:00
# 91    2018-01-08 13:29:39+00:00
# 97    2018-01-08 02:29:55+00:00
# 100   2018-01-07 02:29:43+00:00
# 106   2018-01-06 02:29:21+00:00
# 112   2018-01-05 09:18:32+00:00
# 118   2018-01-04 09:18:29+00:00
# 124   2018-01-03 09:17:58+00:00
# 130   2018-01-02 09:17:44+00:00
# 136   2018-01-01 19:17:28+00:00
# 142   2018-01-01 04:17:43+00:00
# 148   2017-12-31 13:17:42+00:00
# 151   2017-12-31 07:17:48+00:00
# 157   2017-12-30 07:17:42+00:00
# 163   2017-12-29 17:16:39+00:00
# 169   2017-12-29 03:17:40+00:00
# 172   2017-12-28 13:18:09+00:00
# ...                         ...
# 32397 2017-10-21 17:03:09+00:00
# 32398 2017-10-21 17:02:07+00:00
# 32399 2017-10-21 17:01:21+00:00
# 32419 2017-10-21 16:13:43+00:00
# 32430 2017-10-21 16:01:19+00:00
# 32489 2017-10-21 14:05:37+00:00
# 32491 2017-10-21 14:04:15+00:00
# 32496 2017-10-21 13:43:13+00:00
# 32497 2017-10-21 13:43:01+00:00
# 32502 2017-10-21 13:33:35+00:00
# 32503 2017-10-21 13:31:27+00:00
# 32507 2017-10-21 13:19:33+00:00
# 32510 2017-10-21 13:16:39+00:00
# 32514 2017-10-21 13:12:06+00:00
# 32527 2017-10-21 13:02:30+00:00
# 32545 2017-10-21 12:43:20+00:00
# 32546 2017-10-21 12:42:50+00:00
# 32556 2017-10-21 12:22:38+00:00
# 32633 2017-10-21 11:01:58+00:00
# 32636 2017-10-21 11:00:40+00:00
# 32640 2017-10-21 10:59:26+00:00
# 32895 2017-10-21 05:43:49+00:00
# 32897 2017-10-21 05:42:29+00:00
# 32976 2017-10-21 03:10:20+00:00
# 32979 2017-10-21 03:09:46+00:00
# 32995 2017-10-21 02:56:32+00:00
# 33185 2017-10-20 22:12:08+00:00
# 33186 2017-10-20 22:11:28+00:00
# 33201 2017-10-20 22:05:44+00:00
# 33218 2017-10-20 22:01:16+00:00
#
# [2456 rows x 5 columns]

# %%
## Setting the timestamp as index for plotting price trends
uwta_m4.set_index('Timestamp',inplace=True)

## dropping other columns 
for col in ['InstanceType', 'AvailabilityZone', 'ProductDescription']:
    uwta_m4 = uwta_m4.drop(col, axis=1)

## Converting the dtype of spot price to numberic
uwta_m4['SpotPrice'] = uwta_m4['SpotPrice'].apply(pd.to_numeric)

## resample the data with the required frequency
uwta_m4_day = uwta_m4.resample('D').mean()

## resampling with frequency hour
uwta_m4_hour = uwta_m4.resample('H').mean()

uwta_m4_hour
# Out:
#                            SpotPrice
# Timestamp
# 2017-10-20 22:00:00+00:00   0.029750
# 2017-10-20 23:00:00+00:00        NaN
# 2017-10-21 00:00:00+00:00        NaN
# 2017-10-21 01:00:00+00:00        NaN
# 2017-10-21 02:00:00+00:00   0.029600
# 2017-10-21 03:00:00+00:00   0.029650
# 2017-10-21 04:00:00+00:00        NaN
# 2017-10-21 05:00:00+00:00   0.029650
# 2017-10-21 06:00:00+00:00        NaN
# 2017-10-21 07:00:00+00:00        NaN
# 2017-10-21 08:00:00+00:00        NaN
# 2017-10-21 09:00:00+00:00        NaN
# 2017-10-21 10:00:00+00:00   0.029700
# 2017-10-21 11:00:00+00:00   0.029650
# 2017-10-21 12:00:00+00:00   0.029633
# 2017-10-21 13:00:00+00:00   0.029650
# 2017-10-21 14:00:00+00:00   0.029650
# 2017-10-21 15:00:00+00:00        NaN
# 2017-10-21 16:00:00+00:00   0.029650
# 2017-10-21 17:00:00+00:00   0.029650
# 2017-10-21 18:00:00+00:00   0.029600
# 2017-10-21 19:00:00+00:00        NaN
# 2017-10-21 20:00:00+00:00        NaN
# 2017-10-21 21:00:00+00:00   0.029650
# 2017-10-21 22:00:00+00:00        NaN
# 2017-10-21 23:00:00+00:00        NaN
# 2017-10-22 00:00:00+00:00        NaN
# 2017-10-22 01:00:00+00:00        NaN
# 2017-10-22 02:00:00+00:00        NaN
# 2017-10-22 03:00:00+00:00        NaN
# ...                              ...
# 2018-01-16 07:00:00+00:00   0.030100
# 2018-01-16 08:00:00+00:00        NaN
# 2018-01-16 09:00:00+00:00        NaN
# 2018-01-16 10:00:00+00:00        NaN
# 2018-01-16 11:00:00+00:00        NaN
# 2018-01-16 12:00:00+00:00        NaN
# 2018-01-16 13:00:00+00:00        NaN
# 2018-01-16 14:00:00+00:00        NaN
# 2018-01-16 15:00:00+00:00        NaN
# 2018-01-16 16:00:00+00:00        NaN
# 2018-01-16 17:00:00+00:00        NaN
# 2018-01-16 18:00:00+00:00        NaN
# 2018-01-16 19:00:00+00:00        NaN
# 2018-01-16 20:00:00+00:00        NaN
# 2018-01-16 21:00:00+00:00   0.030100
# 2018-01-16 22:00:00+00:00        NaN
# 2018-01-16 23:00:00+00:00        NaN
# 2018-01-17 00:00:00+00:00        NaN
# 2018-01-17 01:00:00+00:00        NaN
# 2018-01-17 02:00:00+00:00        NaN
# 2018-01-17 03:00:00+00:00        NaN
# 2018-01-17 04:00:00+00:00        NaN
# 2018-01-17 05:00:00+00:00        NaN
# 2018-01-17 06:00:00+00:00        NaN
# 2018-01-17 07:00:00+00:00        NaN
# 2018-01-17 08:00:00+00:00        NaN
# 2018-01-17 09:00:00+00:00        NaN
# 2018-01-17 10:00:00+00:00        NaN
# 2018-01-17 11:00:00+00:00        NaN
# 2018-01-17 12:00:00+00:00   0.030100
#
# [2127 rows x 1 columns]

# %% [markdown]
# The resampled data has NaN values as there was no price history at that point of time. Amazon provides the price at a timestamp when there is a change in the price. For a continuous timeseries we can use the forward fill. The idea is the price remains same as current price till the next change is observed.

# %%
uwta_m4_hour.fillna(method='ffill',inplace=True)
uwta_m4_hour
# Out:
#                            SpotPrice
# Timestamp
# 2017-10-20 22:00:00+00:00   0.029750
# 2017-10-20 23:00:00+00:00   0.029750
# 2017-10-21 00:00:00+00:00   0.029750
# 2017-10-21 01:00:00+00:00   0.029750
# 2017-10-21 02:00:00+00:00   0.029600
# 2017-10-21 03:00:00+00:00   0.029650
# 2017-10-21 04:00:00+00:00   0.029650
# 2017-10-21 05:00:00+00:00   0.029650
# 2017-10-21 06:00:00+00:00   0.029650
# 2017-10-21 07:00:00+00:00   0.029650
# 2017-10-21 08:00:00+00:00   0.029650
# 2017-10-21 09:00:00+00:00   0.029650
# 2017-10-21 10:00:00+00:00   0.029700
# 2017-10-21 11:00:00+00:00   0.029650
# 2017-10-21 12:00:00+00:00   0.029633
# 2017-10-21 13:00:00+00:00   0.029650
# 2017-10-21 14:00:00+00:00   0.029650
# 2017-10-21 15:00:00+00:00   0.029650
# 2017-10-21 16:00:00+00:00   0.029650
# 2017-10-21 17:00:00+00:00   0.029650
# 2017-10-21 18:00:00+00:00   0.029600
# 2017-10-21 19:00:00+00:00   0.029600
# 2017-10-21 20:00:00+00:00   0.029600
# 2017-10-21 21:00:00+00:00   0.029650
# 2017-10-21 22:00:00+00:00   0.029650
# 2017-10-21 23:00:00+00:00   0.029650
# 2017-10-22 00:00:00+00:00   0.029650
# 2017-10-22 01:00:00+00:00   0.029650
# 2017-10-22 02:00:00+00:00   0.029650
# 2017-10-22 03:00:00+00:00   0.029650
# ...                              ...
# 2018-01-16 07:00:00+00:00   0.030100
# 2018-01-16 08:00:00+00:00   0.030100
# 2018-01-16 09:00:00+00:00   0.030100
# 2018-01-16 10:00:00+00:00   0.030100
# 2018-01-16 11:00:00+00:00   0.030100
# 2018-01-16 12:00:00+00:00   0.030100
# 2018-01-16 13:00:00+00:00   0.030100
# 2018-01-16 14:00:00+00:00   0.030100
# 2018-01-16 15:00:00+00:00   0.030100
# 2018-01-16 16:00:00+00:00   0.030100
# 2018-01-16 17:00:00+00:00   0.030100
# 2018-01-16 18:00:00+00:00   0.030100
# 2018-01-16 19:00:00+00:00   0.030100
# 2018-01-16 20:00:00+00:00   0.030100
# 2018-01-16 21:00:00+00:00   0.030100
# 2018-01-16 22:00:00+00:00   0.030100
# 2018-01-16 23:00:00+00:00   0.030100
# 2018-01-17 00:00:00+00:00   0.030100
# 2018-01-17 01:00:00+00:00   0.030100
# 2018-01-17 02:00:00+00:00   0.030100
# 2018-01-17 03:00:00+00:00   0.030100
# 2018-01-17 04:00:00+00:00   0.030100
# 2018-01-17 05:00:00+00:00   0.030100
# 2018-01-17 06:00:00+00:00   0.030100
# 2018-01-17 07:00:00+00:00   0.030100
# 2018-01-17 08:00:00+00:00   0.030100
# 2018-01-17 09:00:00+00:00   0.030100
# 2018-01-17 10:00:00+00:00   0.030100
# 2018-01-17 11:00:00+00:00   0.030100
# 2018-01-17 12:00:00+00:00   0.030100
#
# [2127 rows x 1 columns]

# %%
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

## plotting for the day frequency; remember we did not fill the values for day frequency
plt.plot(uwta_m4_day)

# %% [markdown]
# Even though we did not fill in the values for the daily frequency we obtained a continuous which means the price changed atleast once in a day. Now below is the plot for the hourly frequency.

# %%
plt.plot(uwta_m4_hour)

# %% [markdown]
# Interpreting the data as timeseries we can plot the rolling statistics.

# %%
## Rolling statistics
rolmean = uwta_m4_day.rolling(window = 7).mean()
rolstd = uwta_m4_day.rolling(window = 7).std()

## plot the results
orig = plt.plot(uwta_m4_day, color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# ### Test for stationarity
#
# We can test the data for stationarity using the dickney Fuller test.

# %%
## Dickney Fuller test for stationarity
from statsmodels.tsa.stattools import adfuller

x = uwta_m4_day.SpotPrice
x
# Out:
# Timestamp
# 2017-10-20 00:00:00+00:00    0.029750
# 2017-10-21 00:00:00+00:00    0.029647
# 2017-10-22 00:00:00+00:00    0.029600
# 2017-10-23 00:00:00+00:00    0.029770
# 2017-10-24 00:00:00+00:00    0.030073
# 2017-10-25 00:00:00+00:00    0.029814
# 2017-10-26 00:00:00+00:00    0.029785
# 2017-10-27 00:00:00+00:00    0.029743
# 2017-10-28 00:00:00+00:00    0.030221
# 2017-10-29 00:00:00+00:00    0.029905
# 2017-10-30 00:00:00+00:00    0.030186
# 2017-10-31 00:00:00+00:00    0.030079
# 2017-11-01 00:00:00+00:00    0.029667
# 2017-11-02 00:00:00+00:00    0.030037
# 2017-11-03 00:00:00+00:00    0.030229
# 2017-11-04 00:00:00+00:00    0.029905
# 2017-11-05 00:00:00+00:00    0.029800
# 2017-11-06 00:00:00+00:00    0.029970
# 2017-11-07 00:00:00+00:00    0.030148
# 2017-11-08 00:00:00+00:00    0.030157
# 2017-11-09 00:00:00+00:00    0.030504
# 2017-11-10 00:00:00+00:00    0.030694
# 2017-11-11 00:00:00+00:00    0.030209
# 2017-11-12 00:00:00+00:00    0.030209
# 2017-11-13 00:00:00+00:00    0.030820
# 2017-11-14 00:00:00+00:00    0.030925
# 2017-11-15 00:00:00+00:00    0.036655
# 2017-11-16 00:00:00+00:00    0.030348
# 2017-11-17 00:00:00+00:00    0.030061
# 2017-11-18 00:00:00+00:00    0.029769
#                                ...
# 2017-12-19 00:00:00+00:00    0.030100
# 2017-12-20 00:00:00+00:00    0.030100
# 2017-12-21 00:00:00+00:00    0.030100
# 2017-12-22 00:00:00+00:00    0.030100
# 2017-12-23 00:00:00+00:00    0.030100
# 2017-12-24 00:00:00+00:00    0.030100
# 2017-12-25 00:00:00+00:00    0.030100
# 2017-12-26 00:00:00+00:00    0.030100
# 2017-12-27 00:00:00+00:00    0.030100
# 2017-12-28 00:00:00+00:00    0.030100
# 2017-12-29 00:00:00+00:00    0.030100
# 2017-12-30 00:00:00+00:00    0.030100
# 2017-12-31 00:00:00+00:00    0.030100
# 2018-01-01 00:00:00+00:00    0.030100
# 2018-01-02 00:00:00+00:00    0.030100
# 2018-01-03 00:00:00+00:00    0.030100
# 2018-01-04 00:00:00+00:00    0.030100
# 2018-01-05 00:00:00+00:00    0.030100
# 2018-01-06 00:00:00+00:00    0.030100
# 2018-01-07 00:00:00+00:00    0.030100
# 2018-01-08 00:00:00+00:00    0.030100
# 2018-01-09 00:00:00+00:00    0.030100
# 2018-01-10 00:00:00+00:00    0.030100
# 2018-01-11 00:00:00+00:00    0.030100
# 2018-01-12 00:00:00+00:00    0.030100
# 2018-01-13 00:00:00+00:00    0.030100
# 2018-01-14 00:00:00+00:00    0.030100
# 2018-01-15 00:00:00+00:00    0.030100
# 2018-01-16 00:00:00+00:00    0.030100
# 2018-01-17 00:00:00+00:00    0.030100
# Freq: D, Name: SpotPrice, Length: 90, dtype: float64

# %%
res = adfuller(x)

# %%
dfoutput = pd.Series(res[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in res[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -7.433323e+00
# p-value                        6.276975e-11
# #Lags Used                     0.000000e+00
# Number of Observations Used    8.900000e+01
# Critical Value (1%)           -3.506057e+00
# Critical Value (5%)           -2.894607e+00
# Critical Value (10%)          -2.584410e+00
# dtype: float64

# %% [markdown]
# From the results we can be sure that the data we have is not stationary.
